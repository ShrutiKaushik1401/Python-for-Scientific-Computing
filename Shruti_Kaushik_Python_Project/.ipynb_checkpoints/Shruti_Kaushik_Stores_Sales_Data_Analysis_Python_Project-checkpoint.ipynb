# %%
print("Shruti Kaushik Python Project 2. \n" 
      "Please  change the directory path of the file in below Load_Text command. \n")

'''Project Objective and Data - To perform data analysis on the Store Sales data and 
understand the customer's purchase patterns such as - 
•How many customers have purchased an item of particular category?
•Which customers have purchased items of all categories?
•How many customers have purchased items of only few categories? etc.'''

# 1- Import the required libraries
import pandas as pd
import numpy as np
from matplotlib import pylab as plb


# 2 - Load the Sales dataset from a text file to pandas dataframe
df_Store_Sales = pd.read_table(r'C:\Users\ShrutiK\Python for Data Analysis and Scientific Computing\Shruti_Kaushik_Python_Project\Sales Dataset.txt'
   , delimiter=',', usecols=[0,1,3,4,5,7])

df_Store_Sales = pd.DataFrame(df_Store_Sales)

#Create a numpy array for the sales dataset
arr_Store_Sales = df_Store_Sales.values
print(arr_Store_Sales)
                                            
#Get the aggregated Sale Price for the orders for each category
x = df_Store_Sales.groupby('Category')['Unit_Price'].sum()
print(x)

#Get the unique category of sales
y = np.unique(arr_Store_Sales[:,2])
print(y)

#Plot the sales for each category
fig = plb.figure(figsize=(10,6), dpi=120)
plb.figure("Categorical Sales")
plb.axes([0.035,0.035,0.9,0.9])
colormap = plb.cm.Dark2.colors 
plb.cla()
plb.pie(x,labels=y,colors=colormap,radius=.75,autopct='%1.2f%%', shadow=True,startangle=15)
#we set the aspect ratio to 'equal' so the pie is drawn in circle
plb.axis('equal')
plb.xticks(())
plb.yticks(())
plb.show()
plb.pause(1)
print('\n From the pie chart, we can conclude that majority of the customers buy Hat from the store \n ')

#Create the sets for each category and Initialize them to empty values:
Beer = set()
Sunscreen = set()
Hat = set()

#Read each line of the file, get the customer information and add to the appropriate set. 
for row in arr_Store_Sales:
        customer = (row[0],row[1])
        category = row[2]
        if category == "Beer":
                Beer.add(customer)
        if category == "Sunscreen":
                Sunscreen.add(customer)
        if category == "Hat":
                Hat.add(customer)
                
#Print the customers for each category                
print('\n Customers purchasing Beer are: \n', Beer)
print('\n Customers purchasing Sunscreen are: \n',Sunscreen)
print('\n Customers purchasing Hat are: \n',Hat)

#Performing Data analysis 
print("%s customers have purchased Beer" % len(Beer))
print("%s customers have purchased Sunscreen" % len(Sunscreen))
print("%s customers have purchased Hat" % len(Hat))
print("%s customers have purchased Hat and Sunscreen" % len(Hat & Sunscreen))
print("%s customers have purchased Beer and Sunscreen" % len(Beer & Sunscreen))
print("%s customers have purchased Beer, Sunscreen and Hat" % len(Beer & Sunscreen & Hat))
print("\n The following customers are our most valued customers as they have purchased all the 3 items: \n")
for customer in Beer & Sunscreen & Hat:
        print(customer)

print("\n Shruti Kaushik Python Project 2 finishes here.\n")
# Out:
# Shruti Kaushik Python Project 2.
# Please  change the directory path of the file in below Load_Text command.
#
# [[803666 'Fritsch-Glover' 'Sunscreen' 1 98.98 '2014-09-28 11:56:02']
#  [64898 "O'Conner Inc" 'Hat' 9 34.8 '2014-04-24 16:51:22']
#  [423621 'Beatty and Sons' 'Hat' 12 60.24 '2014-09-17 17:26:22']
#  ...
#  [23749 'Bogisich and Sons' 'Beer' 18 54.79 '2014-03-10 08:11:59']
#  [172519 'Kutch, Cormier and Harber' 'Hat' 15 62.53 '2014-04-11 02:50:03']
#  [914594 'Roberts, Volkman and Batz' 'Hat' 11 86.4 '2014-02-14 20:10:42']]
# Category
# Beer         16111.60
# Hat          28458.98
# Sunscreen     9495.85
# Name: Unit_Price, dtype: float64
# ['Beer' 'Hat' 'Sunscreen']
#  From the pie chart, we can conclude that majority of the customers buy Hat from the store
#
#
#  Customers purchasing Beer are:
#  {(744435, 'Marvin, Schroeder and Herman'), (602985, 'Raynor, Bartell and Jakubowski'), (865754, 'Nader, Funk and Dooley'), (438999, 'Kozey Ltd'), (15419, 'Bruen Group'), (821542, 'Heaney-Hilll'), (930909, 'Hilll, Gleichner and Corwin'), (119756, 'Paucek, Schmeler and Runte'), (612001, 'Daniel, Russel and Stoltenberg'), (841645, 'Murray, Herzog and Treutel'), (947492, 'Ryan LLC'), (789704, 'Sporer, Hickle and Steuber'), (531597, 'Rath Ltd'), (527078, 'Kuvalis-Roberts'), (572479, 'Tillman LLC'), (245156, 'Herzog-Homenick'), (172519, 'Kutch, Cormier and Harber'), (304649, 'Kutch, Sauer and Block'), (185412, 'Goyette, Kessler and Goodwin'), (292165, 'Luettgen PLC'), (365312, 'Hermann, Jakubowski and Gaylord'), (964344, 'Hamill and Sons'), (83402, 'Boehm-Beier'), (119873, 'Hane, Goldner and Deckow'), (402109, 'Legros, Dare and Denesik'), (734065, 'Pacocha, White and Lind'), (689693, 'Howe, Witting and Luettgen'), (757632, 'Breitenberg-Harvey'), (761873, 'Lesch, Von and Dooley'), (914594, 'Roberts, Volkman and Batz'), (701170, 'Rau, Bernhard and Parker'), (771001, 'Bechtelar-Schimmel'), (271303, 'Effertz-Hoppe'), (5971, 'Rogahn-Towne'), (306938, "D'Amore PLC"), (374609, 'Homenick, Roob and Beatty'), (54152, 'Cummerata Ltd'), (485244, 'Durgan Ltd'), (305127, 'Zieme-Corkery'), (707783, 'Sanford-Jacobs'), (492837, 'Hamill, Bailey and Schamberger'), (280956, 'McDermott, Hagenes and Hudson'), (826437, 'Halvorson and Sons'), (585977, 'Rohan-Thiel'), (555482, 'Bergstrom, Medhurst and Zieme'), (860172, 'Abshire LLC'), (984152, 'Wiegand, McGlynn and Koss'), (911360, 'Fisher, Wuckert and Smitham'), (320340, 'Casper-Beahan'), (335539, 'Price Group'), (166594, 'Jacobs, Stiedemann and Beatty'), (19767, 'Pagac, Rogahn and Larson'), (679130, 'Berge and Sons'), (194257, 'Kuhn PLC'), (369229, 'Bartell-Kulas'), (570110, 'Pollich Inc'), (4450, 'Beier-Bosco'), (513158, "Rogahn-D'Amore"), (756387, 'Walsh and Sons'), (444226, "O'Conner, Hegmann and Harris"), (291673, 'Kuhlman Inc'), (944406, 'Borer Inc'), (686172, 'Feeney-Kessler'), (481960, 'Rodriguez-Nikolaus'), (212487, 'Von-Ledner'), (600954, 'Bartell, Cronin and Abbott'), (186272, 'Kuhn Inc'), (41295, 'Gulgowski-Luettgen'), (190550, 'Marvin, Johnson and McDermott'), (143837, 'Jast, Abshire and Jast'), (809276, 'Welch, Johnston and Berge'), (763381, 'Weimann LLC'), (166100, 'Bruen-Batz'), (38032, 'Lemke, Kovacek and McClure'), (558485, 'Labadie-Zemlak'), (861533, 'Beatty, Kuhn and Lang'), (896864, 'Johns, Herman and Prosacco'), (858206, 'Conn, Kub and Collier'), (62804, 'Mitchell-Langworth'), (785842, 'Balistreri-Ward'), (794594, 'Swift Group'), (666731, 'Quigley-Terry'), (931007, 'Will, Schamberger and Wehner'), (175408, 'Hoppe and Sons'), (330111, 'Harber Ltd'), (218356, 'Bergnaum-Green'), (406764, 'VonRueden, Ritchie and Reilly'), (269278, 'Luettgen-Ritchie'), (998940, 'Walker-Erdman'), (659158, 'Swift-Okuneva'), (84372, 'Mitchell Ltd'), (401524, 'Rolfson PLC'), (140484, "Aufderhar-O'Hara"), (958246, 'Corkery-Armstrong'), (326369, 'Schmitt-Bruen'), (304798, 'Jerde-Schinner'), (884187, 'Monahan, Bogan and White'), (178236, 'Kris and Sons'), (799421, 'Schultz Group'), (959810, 'Price, Bernhard and Bogisich'), (168893, 'Stoltenberg, Berge and Roberts'), (189941, 'Brakus, Kuhn and Gusikowski'), (464129, 'Ryan PLC'), (593296, 'Kohler, Schaefer and Schuppe'), (318113, 'Fritsch, Koelpin and Larkin'), (776377, 'Lang Ltd'), (411916, 'Rau PLC'), (180324, 'Reynolds Group'), (989350, 'Lang Ltd'), (214690, 'Shanahan and Sons'), (6782, 'Bechtelar-Johnston'), (430911, 'Abbott PLC'), (428333, 'Corkery-Torphy'), (985991, 'Kuvalis, Beahan and Turcotte'), (651569, 'Ebert, Zemlak and Hills'), (104535, 'Kling and Sons'), (173693, 'Halvorson PLC'), (974584, 'Armstrong, McKenzie and Greenholt'), (740581, 'Ziemann, Reynolds and McClure'), (70143, 'Carroll-Morissette'), (40033, 'Schamberger, Hudson and Kuhic'), (780068, 'Stroman-Adams'), (31937, 'Orn-Pfannerstill'), (80571, 'Simonis, Johnston and Jewess'), (622744, 'Nade ...
#
#  Customers purchasing Sunscreen are:
#  {(438999, 'Kozey Ltd'), (602985, 'Raynor, Bartell and Jakubowski'), (971908, 'Bauch-Skiles'), (930552, 'Baumbach, Bogan and Feeney'), (539788, 'Lindgren, Bergnaum and Bosco'), (172430, "Legros, Stoltenberg and O'Keefe"), (626759, 'Stracke, Lemke and Gutkowski'), (391072, 'Ledner and Sons'), (399401, 'Schneider, Kreiger and Hahn'), (726918, 'Schmidt, Oberbrunner and Beier'), (461425, "O'Conner PLC"), (648900, 'Lind-Spencer'), (254523, 'Pacocha-Abbott'), (527078, 'Kuvalis-Roberts'), (163875, 'McDermott, Gerlach and Bechtelar'), (292165, 'Luettgen PLC'), (573823, 'Macejkovic, Kemmer and Daniel'), (845182, "Hudson, O'Reilly and Murphy"), (936362, 'Goodwin Group'), (653523, 'Braun LLC'), (314575, 'Mraz, Romaguera and Schiller'), (687391, 'Thiel Ltd'), (651033, 'Rice Ltd'), (485244, 'Durgan Ltd'), (707783, 'Sanford-Jacobs'), (83845, 'Wisozk-Funk'), (17915, 'Huel Inc'), (896778, 'Kuvalis-Harvey'), (36881, 'Hahn, Johnson and Jacobi'), (702153, 'Kautzer-Rolfson'), (201942, 'Swaniawski Inc'), (320340, 'Casper-Beahan'), (335539, 'Price Group'), (166594, 'Jacobs, Stiedemann and Beatty'), (979589, 'Brown Inc'), (19767, 'Pagac, Rogahn and Larson'), (70851, 'Conroy-Schaden'), (383619, 'Becker Ltd'), (846832, 'Baumbach Group'), (4450, 'Beier-Bosco'), (567684, 'Conroy, Hermann and Fay'), (291673, 'Kuhlman Inc'), (461185, 'Witting, Anderson and Graham'), (365614, 'Kertzmann, Hodkiewicz and Kohler'), (190550, 'Marvin, Johnson and McDermott'), (881909, 'Ratke-Mitchell'), (320821, 'Lockman LLC'), (116357, 'Terry PLC'), (79480, 'Kautzer LLC'), (198887, 'Shanahan-Bartoletti'), (726713, 'Schinner-Baumbach'), (705775, 'Wilderman Group'), (931007, 'Will, Schamberger and Wehner'), (597068, 'Spencer-Watsica'), (341067, 'Lesch-Lang'), (330111, 'Harber Ltd'), (556347, "O'Connell, Huel and Kunde"), (169658, 'Mitchell PLC'), (630644, 'Kerluke, Barton and Koch'), (285621, 'Waters Ltd'), (460436, 'Baumbach LLC'), (692143, 'Kreiger Ltd'), (195246, 'Hammes-Haag'), (995224, 'Macejkovic Inc'), (644131, 'Batz-Dare'), (829783, 'Hyatt-Rohan'), (170224, 'Grimes, Walker and Schowalter'), (355459, 'Rosenbaum Ltd'), (558940, 'Klocko Inc'), (45241, "O'Keefe LLC"), (625319, 'Wiegand, Kemmer and Kling'), (788245, 'Sipes, Stehr and Pacocha'), (407134, 'Bailey, Ernser and Bashirian'), (708467, 'Homenick-Cremin'), (173693, 'Halvorson PLC'), (23156, 'Kuhn and Sons'), (473322, 'Schuppe-Frami'), (442413, 'Schmeler, Greenholt and Pagac'), (140793, 'Kulas-Olson'), (957040, 'Bernhard, Price and Bogan'), (206192, 'Nicolas-Emard'), (512839, 'Moen LLC'), (346709, 'Cole Inc'), (88948, 'Schulist-Stokes'), (892834, 'Bode, Greenholt and Lang'), (222704, 'Ernser-Dare'), (991343, 'Brekke PLC'), (352112, 'Ortiz-Kemmer'), (516157, 'Kuhn-Crist'), (192300, 'Wiza, Schneider and Parker'), (378288, 'Cronin PLC'), (482364, 'Armstrong-Williamson'), (647742, 'Swaniawski, Hettinger and Dickinson'), (910599, 'Haag-Huel'), (943137, 'Walter-Witting'), (510762, 'Carroll-Kunde'), (41711, 'Koepp-McLaughlin'), (685048, 'Schultz Group'), (930445, 'Kuhlman-Abbott'), (954888, 'Douglas, Monahan and Beier'), (116928, 'Sporer, Collins and Gutkowski'), (24024, 'Cruickshank, Robel and Jast'), (838999, 'Runolfsson-Bernier'), (86467, 'Bechtelar-Windler'), (435351, 'Beahan-Lockman'), (389408, 'Koch-Ledner'), (310730, 'Wolf Ltd'), (479110, 'Kilback-Hettinger'), (826893, 'Schinner, Cruickshank and Ziemann'), (185994, 'Murazik LLC'), (290386, "Kreiger-O'Connell"), (334055, 'Herman Ltd'), (795299, 'King, DuBuque and Gorczany'), (50180, 'Legros-Larson'), (321146, 'Stroman-Ortiz'), (386739, 'Schmidt, Crona and Kilback'), (433327, 'Zulauf-Will'), (803666, 'Fritsch-Glover'), (951852, 'Jenkins Ltd'), (40995, 'McLaughlin, McKenzie and Kulas'), (337183, 'Batz, Nienow and Jenkins'), (727064, 'Bashirian, Beier and Watsica'), (916492, 'Kohler Ltd'), (262918, 'Beahan, Hackett and Hagenes'), (722921, 'Thompson-Gislason'), (145616, 'Wiza, Nolan and Johns'), (852731, 'Leuschke, Haley and Green'), (459388, 'Labadie, Vandervort and Johns' ...
#
#  Customers purchasing Hat are:
#  {(94413, 'Watsica-Shanahan'), (117149, 'Koepp, Witting and Collier'), (716142, 'Stroman-Grimes'), (300064, 'Streich, Hermiston and Walsh'), (356187, 'Stanton, Hills and Rolfson'), (680569, 'Cummerata, Ryan and Moen'), (217066, 'Raynor LLC'), (789704, 'Sporer, Hickle and Steuber'), (361615, 'Kreiger, Satterfield and Mertz'), (549196, 'Kuphal, Hand and Larkin'), (486457, 'Balistreri-Jewess'), (527078, 'Kuvalis-Roberts'), (924946, 'Bednar, Flatley and Kozey'), (750871, 'Cremin PLC'), (539422, 'Weber and Sons'), (836156, 'Ruecker Ltd'), (629547, 'Thiel-Volkman'), (915519, 'Will-Hoeger'), (883455, 'Collins-Bartell'), (54152, 'Cummerata Ltd'), (269580, 'Shields-Boyer'), (435433, 'Morissette-Heathcote'), (860172, 'Abshire LLC'), (727648, 'Bernhard, Muller and Adams'), (655756, 'Sipes, Fadel and Schamberger'), (88092, 'Spinka, Morissette and Schinner'), (881909, 'Ratke-Mitchell'), (995788, 'Feil and Sons'), (198887, 'Shanahan-Bartoletti'), (50523, 'Stamm, Oberbrunner and Hills'), (484679, 'King and Sons'), (296008, 'Greenholt, Stroman and Waelchi'), (894083, 'Kiehn-Mueller'), (584906, 'Turcotte, Grant and Heidenreich'), (737861, 'Nitzsche Ltd'), (633848, 'Johnston-Dicki'), (39521, 'Wuckert-Yost'), (265759, 'Lockman-Trantow'), (662360, 'Kshlerin-Turcotte'), (792333, 'Conn-McLaughlin'), (494896, 'Luettgen-Johns'), (189941, 'Brakus, Kuhn and Gusikowski'), (233895, 'Gleason-Cremin'), (318113, 'Fritsch, Koelpin and Larkin'), (587760, 'Conn, Schultz and Ullrich'), (510820, 'Fritsch Group'), (918478, 'Lowe, Hamill and Cummings'), (85499, 'Heller-Towne'), (12965, 'Gaylord Inc'), (166245, 'Dietrich LLC'), (246745, 'Hyatt, Brown and Rohan'), (799020, 'Heller Ltd'), (958651, 'Franecki Inc'), (853091, 'Becker PLC'), (222704, 'Ernser-Dare'), (991343, 'Brekke PLC'), (319932, 'Brakus-Lockman'), (104104, "Corkery-O'Connell"), (76895, 'Bartell-Boehm'), (752355, 'Bashirian-Lakin'), (128394, 'Klocko-Kuvalis'), (223656, 'Hoeger-Emard'), (41711, 'Koepp-McLaughlin'), (164962, 'Hudson-Trantow'), (928796, 'Ondricka-Blanda'), (838999, 'Runolfsson-Bernier'), (112088, 'Schoen-Sawayn'), (927597, 'Kunde-Runolfsdottir'), (611543, 'Kilback-Stokes'), (294664, 'Roob, Barton and Kozey'), (668727, 'Schaden and Sons'), (435915, 'Kling, Parker and Goodwin'), (618428, 'McLaughlin PLC'), (573320, 'Hickle Ltd'), (957458, 'Tromp Ltd'), (440852, 'Bradtke, Daniel and Hagenes'), (770435, 'Sporer-Denesik'), (19989, 'Sanford, Jakubowski and Haag'), (224745, 'Paucek, Cole and Ebert'), (633200, 'Denesik, Swift and Howell'), (72225, 'Ledner, Koss and Ziemann'), (137198, 'VonRueden, Wiza and Balistreri'), (154512, 'Sauer Group'), (307063, 'Moen, Bernier and Kuhlman'), (423621, 'Beatty and Sons'), (823932, 'Johns, Hermann and Wolf'), (950739, 'Ward LLC'), (40120, 'Borer-Bernier'), (721900, 'Rolfson, Lesch and Pacocha'), (404045, 'Stark-Swaniawski'), (631062, 'Cormier Inc'), (351680, 'Sanford, Mitchell and Nienow'), (243642, 'Paucek-Stehr'), (345258, 'Heaney-Satterfield'), (455768, 'Sawayn-Treutel'), (837097, 'Kihn, Emard and Goldner'), (659579, 'Upton, Hilpert and White'), (779536, 'Champlin-Hodkiewicz'), (272517, 'Davis, Heaney and Johns'), (606477, 'Hilpert, Witting and McDermott'), (137865, 'Gleason, Bogisich and Franecki'), (282674, 'Haley Ltd'), (897322, 'Hilll, Schultz and Braun'), (282942, 'Schinner Group'), (841645, 'Murray, Herzog and Treutel'), (735493, 'Strosin, Nader and Zulauf'), (947492, 'Ryan LLC'), (598556, 'Farrell-Bergnaum'), (423670, 'Schulist-Spencer'), (651647, 'Monahan-Sanford'), (642109, 'Baumbach Group'), (605258, "O'Reilly-Ullrich"), (172519, 'Kutch, Cormier and Harber'), (406858, 'Sawayn-Harris'), (221967, 'Hahn Ltd'), (914594, 'Roberts, Volkman and Batz'), (893804, 'Wilkinson, Spinka and Block'), (801586, 'Watsica PLC'), (711358, 'Wilkinson Ltd'), (958584, 'Gottlieb, Krajcik and Sawayn'), (973981, 'Kutch Inc'), (899300, 'Langworth-Skiles'), (200482, 'Nicolas-Bradtke'), (194257, 'Kuhn PLC'), (878842, 'Durgan and Sons'), (374476, 'Marvin-Moen'), (686172, 'Fee ...
# 271 customers have purchased Beer
# 170 customers have purchased Sunscreen
# 442 customers have purchased Hat
# 57 customers have purchased Hat and Sunscreen
# 31 customers have purchased Beer and Sunscreen
# 9 customers have purchased Beer, Sunscreen and Hat
#
#  The following customers are our most valued customers as they have purchased all the 3 items:
#
# (527078, 'Kuvalis-Roberts')
# (41711, 'Koepp-McLaughlin')
# (173693, 'Halvorson PLC')
# (803666, 'Fritsch-Glover')
# (727064, 'Bashirian, Beier and Watsica')
# (151300, "Upton, Runolfsson and O'Reilly")
# (434955, 'Ledner-Kling')
# (4450, 'Beier-Bosco')
# (343481, 'Mills Inc')
#
#  Shruti Kaushik Python Project 2 finishes here.
